# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from sklearn import preprocessing, metrics
from sklearn.preprocessing import MinMaxScaler
import os
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta 
from typing import Union
from tqdm.notebook import tqdm_notebook as tqdm
from fastprogress import master_bar, progress_bar
from itertools import cycle
import datetime as dt

# matplotlib 설정
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %%
import os
import torch

# Set CUDA_LAUNCH_BLOCKING environment variable to 1
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# Now you can import PyTorch and use the CUDA backend
import torch.cuda

# Rest of your PyTorch code here

# %%
xgb_weights = [3.78227234e-02, 5.35090003e-05, 1.02894781e-04, 1.49786865e-04,
 1.04764847e-04, 1.63700344e-04, 7.86159754e-01, 1.66692644e-01,
 1.62399039e-04, 1.36344403e-04, 1.23864607e-04, 3.25831398e-03,
 1.11413574e-04, 1.12267953e-04, 1.12513058e-04, 1.15435665e-04,
 9.74491413e-05, 7.48724633e-05, 7.42438278e-05, 8.17979526e-05,
 9.10188464e-05, 8.10626516e-05, 1.62408571e-04, 9.22517429e-05,
 6.92411995e-05, 6.06398789e-05, 6.15876997e-05, 2.05707460e-04,
 9.76096126e-05, 9.17855941e-05, 7.44235294e-05, 8.87563365e-05,
 7.44791614e-05, 6.22049338e-05, 6.85490304e-05, 6.57211494e-05,
 6.70680165e-05, 1.42811637e-04, 9.89059918e-05, 9.52478367e-05,
 1.08733664e-04, 8.95528574e-05, 1.07477274e-04, 1.15086681e-04,
 8.60139335e-05, 7.83390569e-05, 6.42610321e-05, 1.03312457e-04,
 9.24527631e-05, 8.45081231e-05, 7.72333588e-05, 8.96328202e-05,
 2.81332632e-05, 2.14036554e-04, 3.18860257e-05, 3.27980561e-05,
 5.04529162e-05, 2.01942370e-04, 7.67721576e-05, 5.93836303e-05,
 6.03012268e-05, 2.65900104e-04, 1.67839185e-04, 8.06350436e-05,
 7.12153196e-05]

tabnet_weights = [4.26892227e-06, 0.00000000e+00, 0.00000000e+00, 3.00723057e-02,
0.00000000e+00, 1.81987064e-06, 1.37099386e-01, 3.07597264e-01,
1.17412334e-05, 0.00000000e+00, 0.00000000e+00, 7.68810592e-02,
6.31930090e-04, 8.53033960e-03, 1.69922775e-02, 8.09343194e-03,
1.85524606e-08, 0.00000000e+00, 5.99931009e-03, 0.00000000e+00,
0.00000000e+00, 0.00000000e+00, 7.60999255e-05, 1.14790590e-06,
1.17366399e-01, 1.14198997e-02, 0.00000000e+00, 3.89959469e-06,
0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.32325158e-05,
0.00000000e+00, 6.57038847e-05, 1.35262607e-02, 2.21752146e-05,
0.00000000e+00, 6.23984265e-02, 8.66896181e-03, 0.00000000e+00,
2.79329075e-03, 1.93734536e-06, 9.73141818e-04, 0.00000000e+00,
2.06456979e-06, 5.23236864e-02, 1.94160263e-02, 4.95664089e-03,
8.15198301e-04, 4.23687933e-02, 4.42582323e-03, 1.96317046e-02,
0.00000000e+00, 2.24109549e-03, 0.00000000e+00, 3.52501762e-03,
4.90427532e-03, 0.00000000e+00, 2.95825462e-03, 0.00000000e+00,
4.75344631e-03, 5.37095814e-03, 0.00000000e+00, 8.05441066e-04,
2.21958440e-02]
regular_weights = [1] * 65

# %%
for i in range(len(xgb_weights)):
    tabnet_weights[i] += (0.001*xgb_weights[i])

# %%
train = pd.read_pickle('train.pkl')
test = pd.read_pickle('test.pkl')
val = pd.read_pickle('val.pkl')

# Create a dictionary to map feature names to tabnet_weights
tabnet_weight_dict_train = {col: weight for col, weight in zip(train.columns, tabnet_weights)}
tabnet_weight_dict_test = {col: weight for col, weight in zip(test.columns, tabnet_weights)}
tabnet_weight_dict_val = {col: weight for col, weight in zip(val.columns, tabnet_weights)}

# Apply tabnet_weights to train, test, and val DataFrames
tabnet_train = train * pd.Series(tabnet_weight_dict_train)
tabnet_test = test * pd.Series(tabnet_weight_dict_test)
tabnet_val = val * pd.Series(tabnet_weight_dict_val)

#Now to do same for xgb
# Create a dictionary to map feature names to tabnet_weights
xgb_weight_dict_train = {col: weight for col, weight in zip(train.columns, xgb_weights)}
xgb_weight_dict_test = {col: weight for col, weight in zip(test.columns, xgb_weights)}
xgb_weight_dict_val = {col: weight for col, weight in zip(val.columns, xgb_weights)}

#xgb_weights to train, test, and val DataFrames
xgb_train = train * pd.Series(xgb_weight_dict_train)
xgb_test = test * pd.Series(xgb_weight_dict_test)
xgb_val = val * pd.Series(xgb_weight_dict_val)

# %%
import data_preprocess as dpf

xgb_train_norm = dpf.normalize_all(xgb_train)
xgb_test_norm = dpf.normalize_all(xgb_test)
xgb_val_norm = dpf.normalize_all(xgb_val)

tabnet_train_norm = dpf.normalize_all(tabnet_train)
tabnet_test_norm = dpf.normalize_all(tabnet_test)
tabnet_val_norm = dpf.normalize_all(tabnet_val)

# %%
train_indices = tabnet_train_norm.index
valid_indices = tabnet_val_norm.index
test_indices = tabnet_test_norm.index

# %%
target = 'Power (kW)'
features = [ col for col in tabnet_train_norm.columns if col not in target]

# %%
tabnet_X_train = tabnet_train_norm[features].values[train_indices]
tabnet_y_train = tabnet_train_norm[target].values[train_indices]

tabnet_X_valid = tabnet_val_norm[features].values[valid_indices]
tabnet_y_valid = tabnet_val_norm[target].values[valid_indices]

tabnet_X_test = tabnet_test_norm[features].values[test_indices]
tabnet_y_test = tabnet_test_norm[target].values[test_indices]

# %%
def torch_tensor_creator(df):
    # Convert DataFrame to a numpy array
    data_array = df.values

    # Convert numpy array to a PyTorch tensor
    tensor_data = torch.tensor(data_array, dtype=torch.float)


    # Assuming 'data' is your PyTorch tensor
    has_nans = torch.isnan(tensor_data).any().item()

    if has_nans:
        # Assuming 'tensor_data' is your PyTorch tensor containing the data
    # Find the indices of columns with NaN values
        nan_columns_indices = torch.any(torch.isnan(tensor_data), dim=0).nonzero().squeeze()

        # Remove the columns with NaN values
        tensor_data_without_nan = torch.cat(
            [tensor_data[:, i].unsqueeze(1) for i in range(tensor_data.size(1)) if i not in nan_columns_indices],
            dim=1
        )
    else:
        tensor_data_without_nan = tensor_data
    # Assuming 'data' is your PyTorch tensor
    has_nans = torch.isnan(tensor_data_without_nan)

    # Count the number of NaN values in each column
    num_nans_per_column = torch.sum(has_nans, dim=0)

    return tensor_data_without_nan

# %%
xgb_X_train = torch_tensor_creator(xgb_train_norm[features])
xgb_y_train = torch_tensor_creator(xgb_train_norm[target])
xgb_X_valid = torch_tensor_creator(xgb_val_norm[features])
xgb_y_valid = torch_tensor_creator(xgb_val_norm[target])
xgb_X_test = torch_tensor_creator(xgb_test_norm[features])
xgb_y_test = torch_tensor_creator(xgb_test_norm[target])

# %%
print(xgb_X_train.size())
print(xgb_X_test.size())
print(xgb_y_train.size())
print(xgb_y_test.size())
print(xgb_X_valid.size())
print(xgb_y_valid.size())
# Out:
# torch.Size([78436, 64])
# torch.Size([26146, 64])
# torch.Size([78436])
# torch.Size([26146])
# torch.Size([26146, 64])
# torch.Size([26146])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()
        self.mse = nn.MSELoss()

    def forward(self, pred, target):
        return torch.sqrt(self.mse(pred, target))

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

class EncoderDecoderModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, cnn_kernel_size=6, lstm_num_layers=2):
        super(EncoderDecoderModel, self).__init__()

        # CNN layer
        self.cnn = nn.Conv1d(input_size, hidden_size, cnn_kernel_size, padding=cnn_kernel_size // 2)

        # LSTM layers
        self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers=lstm_num_layers, batch_first=True)

        # Fully connected layer
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # Reshape for CNN input
        x = self.cnn(x)
        x = x.permute(0, 2, 1)  # Reshape back for LSTM input
        _, (hidden, _) = self.lstm(x)
        x = self.fc(hidden[-1])
        return x

# %%
# Assuming you already have the data as tensors, convert them to DataLoader
# Modify the DataLoader to generate batches with the correct shape

# Update the input and output sizes according to your data
input_size = 64  # Number of features in your input data
output_size = 256  # Replace ??? with the number of classes in your classification problem

# ... (Your previous code)

# Reshape the input data to have a 3-dimensional shape (batch_size, seq_length, input_size)
seq_length = 256
overlap = 20  # Adjust the overlap as needed
xgb_X_train_reshaped = []
for i in range(0, xgb_X_train.shape[0] - seq_length + 1, overlap):
    xgb_X_train_reshaped.append(xgb_X_train[i:i+seq_length])
xgb_X_train_reshaped = torch.stack(xgb_X_train_reshaped)

# Similarly, reshape the training target data
xgb_y_train_reshaped = []
for i in range(0, xgb_y_train.shape[0] - seq_length + 1, overlap):
    xgb_y_train_reshaped.append(xgb_y_train[i:i+seq_length])
xgb_y_train_reshaped = torch.stack(xgb_y_train_reshaped)

# Do the same for the validation data
xgb_X_valid_reshaped = []
for i in range(0, xgb_X_valid.shape[0] - seq_length + 1, overlap):
    xgb_X_valid_reshaped.append(xgb_X_valid[i:i+seq_length])
xgb_X_valid_reshaped = torch.stack(xgb_X_valid_reshaped)

# Similarly, reshape the validation target data
xgb_y_valid_reshaped = []
for i in range(0, xgb_y_valid.shape[0] - seq_length + 1, overlap):
    xgb_y_valid_reshaped.append(xgb_y_valid[i:i+seq_length])
xgb_y_valid_reshaped = torch.stack(xgb_y_valid_reshaped)

train_dataset = TensorDataset(xgb_X_train_reshaped, xgb_y_train_reshaped)
valid_dataset = TensorDataset(xgb_X_valid_reshaped, xgb_y_valid_reshaped)

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=False)  # Adjust batch_size as needed
valid_loader = DataLoader(valid_dataset, batch_size=256, shuffle=False)  # Adjust batch_size as needed

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def visualize_predictions(predictions, targets, output_folder):
    os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist
    
    for i in range(len(predictions)):
        fig, ax = plt.subplots(figsize=(5, 5))  # Set the figure size to 500x500 pixels

        ax.plot(np.arange(len(predictions[i])), predictions[i], label='Predicted', marker='o')
        ax.plot(np.arange(len(targets[i])), targets[i], label='Actual', marker='x')
        ax.set_xlabel("Data Index")
        ax.set_ylabel("Values")
        ax.set_title(f"Predictions vs. Actual (Data Point {i + 1})")
        ax.legend()

        plt.tight_layout()  # To prevent overlapping of labels and ticks
        plt.savefig(os.path.join(output_folder, f"plot_{i + 1}.png"))  # Save the plot with a unique name
        plt.close()  # Close the current figure to release memory


output_folder = "output_plots"

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define the RMSE loss function
class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()

    def forward(self, pred, target):
        return torch.sqrt(torch.mean((pred - target) ** 2))
    
import matplotlib.pyplot as plt
import numpy as np
from torch_optimizer import Lookahead




def evaluate_model(model, valid_loader, criterion, device):
    model.eval()
    valid_loss = 0.0
    predictions = []
    targets_list = []
    with torch.no_grad():
        for inputs, targets in valid_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            valid_loss += loss.item()
            
            # Save the predictions and targets for visualization
            predictions.extend(outputs.cpu().numpy())
            targets_list.extend(targets.cpu().numpy())
            
    #if epoch == epochs - 1:
            # Visualize predictions versus actual only in the final epoch
        #visualize_predictions(predictions, targets_list,output_folder)
    
    return valid_loss / len(valid_loader), predictions, targets_list

def train_model(model, train_loader, valid_loader, epochs=100, learning_rate=0.001):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    criterion = RMSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    optimizer = Lookahead(optimizer=optimizer, k=5, alpha=0.5)

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
        
        # Calculate validation loss after each epoch and get predictions for visualization
        valid_loss, predictions, targets_list = evaluate_model(model, valid_loader, criterion, device)
        
        print(f"Epoch {epoch + 1}/{epochs}, Train Loss: {train_loss:.4f}, Valid Loss: {valid_loss:.4f}")
        print(f"RMSE: {np.sqrt(valid_loss):.4f}")
        print({epoch})
        
        #if epoch == epochs - 1:
            # Visualize predictions versus actual only in the final epoch
            #visualize_predictions(predictions, targets_list,output_folder)

# %%
# Set the hyperparameters
input_size = 64  # Update the input size to match the number of features in your input data
hidden_size = 64
output_size = 256
cnn_kernel_size = 3
lstm_num_layers = 1

# Create the model with the corrected input_size
model = EncoderDecoderModel(input_size, hidden_size, output_size, cnn_kernel_size, lstm_num_layers)

# Train the model
train_model(model, train_loader, valid_loader, epochs=500, learning_rate=0.001)
# Out:
# Epoch 1/500, Train Loss: 6.3362, Valid Loss: 0.3204
# RMSE: 0.5660
# {0}
# Epoch 2/500, Train Loss: 5.2882, Valid Loss: 0.2743
# RMSE: 0.5237
# {1}
# Epoch 3/500, Train Loss: 4.8487, Valid Loss: 0.2627
# RMSE: 0.5126
# {2}
# Epoch 4/500, Train Loss: 4.6534, Valid Loss: 0.2554
# RMSE: 0.5054
# {3}
# Epoch 5/500, Train Loss: 4.5126, Valid Loss: 0.2540
# RMSE: 0.5040
# {4}
# Epoch 6/500, Train Loss: 4.4132, Valid Loss: 0.2537
# RMSE: 0.5037
# {5}
# Epoch 7/500, Train Loss: 4.3754, Valid Loss: 0.2537
# RMSE: 0.5037
# {6}
# Epoch 8/500, Train Loss: 4.3414, Valid Loss: 0.2533
# RMSE: 0.5032
# {7}
# Epoch 9/500, Train Loss: 4.2988, Valid Loss: 0.2590
# RMSE: 0.5089
# {8}
# Epoch 10/500, Train Loss: 4.4282, Valid Loss: 0.2520
# RMSE: 0.5020
# {9}
# Epoch 11/500, Train Loss: 4.2429, Valid Loss: 0.2497
# RMSE: 0.4997
# {10}
# Epoch 12/500, Train Loss: 4.2400, Valid Loss: 0.2524
# RMSE: 0.5024
# {11}
# Epoch 13/500, Train Loss: 4.2738, Valid Loss: 0.2463
# RMSE: 0.4962
# {12}
# Epoch 14/500, Train Loss: 4.1469, Valid Loss: 0.2521
# RMSE: 0.5021
# {13}
# Epoch 15/500, Train Loss: 4.2657, Valid Loss: 0.2416
# RMSE: 0.4915
# {14}
# Epoch 16/500, Train Loss: 4.6932, Valid Loss: 0.2571
# RMSE: 0.5070
# {15}
# Epoch 17/500, Train Loss: 4.5064, Valid Loss: 0.2504
# RMSE: 0.5004
# {16}
# Epoch 18/500, Train Loss: 4.2989, Valid Loss: 0.2544
# RMSE: 0.5044
# {17}
# Epoch 19/500, Train Loss: 4.3444, Valid Loss: 0.2496
# RMSE: 0.4996
# {18}
# Epoch 20/500, Train Loss: 4.1672, Valid Loss: 0.2489
# RMSE: 0.4989
# {19}
# Epoch 21/500, Train Loss: 4.0543, Valid Loss: 0.2500
# RMSE: 0.5000
# {20}
# Epoch 22/500, Train Loss: 3.9641, Valid Loss: 0.2434
# RMSE: 0.4934
# {21}
# Epoch 23/500, Train Loss: 3.9901, Valid Loss: 0.2385
# RMSE: 0.4884
# {22}
# Epoch 24/500, Train Loss: 4.0950, Valid Loss: 0.2484
# RMSE: 0.4984
# {23}
# Epoch 25/500, Train Loss: 3.7302, Valid Loss: 0.2338
# RMSE: 0.4835
# {24}
# Epoch 26/500, Train Loss: 3.6894, Valid Loss: 0.2302
# RMSE: 0.4798
# {25}
# Epoch 27/500, Train Loss: 3.6046, Valid Loss: 0.2237
# RMSE: 0.4730
# {26}
# Epoch 28/500, Train Loss: 3.5723, Valid Loss: 0.2321
# RMSE: 0.4817
# {27}
# Epoch 29/500, Train Loss: 3.3629, Valid Loss: 0.2271
# RMSE: 0.4766
# {28}
# Epoch 30/500, Train Loss: 3.2452, Valid Loss: 0.2167
# RMSE: 0.4655
# {29}
# Epoch 31/500, Train Loss: 3.1545, Valid Loss: 0.2228
# RMSE: 0.4721
# {30}
# Epoch 32/500, Train Loss: 3.0700, Valid Loss: 0.2239
# RMSE: 0.4732
# {31}
# Epoch 33/500, Train Loss: 3.0335, Valid Loss: 0.2262
# RMSE: 0.4756
# {32}
# Epoch 34/500, Train Loss: 2.9506, Valid Loss: 0.2259
# RMSE: 0.4753
# {33}
# Epoch 35/500, Train Loss: 2.9586, Valid Loss: 0.2127
# RMSE: 0.4612
# {34}
# Epoch 36/500, Train Loss: 2.9199, Valid Loss: 0.2218
# RMSE: 0.4709
# {35}
# Epoch 37/500, Train Loss: 2.8519, Valid Loss: 0.2130
# RMSE: 0.4615
# {36}
# Epoch 38/500, Train Loss: 2.8836, Valid Loss: 0.2351
# RMSE: 0.4848
# {37}
# Epoch 39/500, Train Loss: 2.8431, Valid Loss: 0.2236
# RMSE: 0.4728
# {38}
# Epoch 40/500, Train Loss: 2.8311, Valid Loss: 0.2248
# RMSE: 0.4741
# {39}
# Epoch 41/500, Train Loss: 2.7605, Valid Loss: 0.2220
# RMSE: 0.4711
# {40}
# Epoch 42/500, Train Loss: 2.7693, Valid Loss: 0.2133
# RMSE: 0.4618
# {41}
# Epoch 43/500, Train Loss: 2.7952, Valid Loss: 0.2456
# RMSE: 0.4956
# {42}
# Epoch 44/500, Train Loss: 2.7647, Valid Loss: 0.2357
# RMSE: 0.4854
# {43}
# Epoch 45/500, Train Loss: 2.7315, Valid Loss: 0.2307
# RMSE: 0.4803
# {44}
# Epoch 46/500, Train Loss: 2.6999, Valid Loss: 0.2222
# RMSE: 0.4713
# {45}
# Epoch 47/500, Train Loss: 2.6994, Valid Loss: 0.2307
# RMSE: 0.4804
# {46}
# Epoch 48/500, Train Loss: 2.7053, Valid Loss: 0.2419
# RMSE: 0.4919
# {47}
# Epoch 49/500, Train Loss: 2.6978, Valid Loss: 0.2277
# RMSE: 0.4772
# {48}
# Epoch 50/500, Train Loss: 2.6213, Valid Loss: 0.2215
# RMSE: 0.4706
# {49}
# Epoch 51/500, Train Loss: 2.5891, Valid Loss: 0.2181
# RMSE: 0.4670
# {50}
# Epoch 52/500, Train Loss: 2.5713, Valid Loss: 0.2173
# RMSE: 0.4662
# {51}
# Epoch 53/500, Train Loss: 2.5744, Valid Loss: 0.2243
# RMSE: 0.4737
# {52}
# Epoch 54/500, Train Loss: 2.5380, Valid Loss: 0.2161
# RMSE: 0.4649
# {53}
# Epoch 55/500, Train Loss: 2.5229, Valid Loss: 0.2314
# RMSE: 0.4810
# {54}
# Epoch 56/500, Train Loss: 2.5316, Valid Loss: 0.2181
# RMSE: 0.4670
# {55}
# Epoch 57/500, Train Loss: 2.4916, Valid Loss: 0.2180
# RMSE: 0.4669
# {56}
# Epoch 58/500, Train Loss: 2.4637, Valid Loss: 0.2342
# RMSE: 0.4840
# {57}
# Epoch 59/500, Train Loss: 2.4426, Valid Loss: 0.2254
# RMSE: 0.4748
# {58}
# Epoch 60/500, Train Loss: 2.4280, Valid Loss: 0.2190
# RMSE: 0.4680
# {59}
# Epoch 61/500, Train Loss: 2.4642, Valid Loss: 0.2225
# RMSE: 0.4717
# {60}
# Epoch 62/500, Train Loss: 2.4127, Valid Loss: 0.2140
# RMSE: 0.4627
# {61}
# Epoch 63/500, Train Loss: 2.4831, Valid Loss: 0.2356
# RMSE: 0.4854
# {62}
# Epoch 64/500, Train Loss: 2.4252, Valid Loss: 0.2373
# RMSE: 0.4872
# {63}
# Epoch 65/500, Train Loss: 2.3918, Valid Loss: 0.2283
# RMSE: 0.4779
# {64}
# Epoch 66/500, Train Loss: 2.4375, Valid Loss: 0.2160
# RMSE: 0.4648
# {65}
# Epoch 67/500, Train Loss: 2.3868, Valid Loss: 0.2134
# RMSE: 0.4619
# {66}
# Epoch 68/500, Train Loss: 2.4196, Valid Loss: 0.2193
# RMSE: 0.4683
# {67}
# Epoch 69/500, Train Loss: 2.3362, Valid Loss: 0.2143
# RMSE: 0.4630
# {68}
# Epoch 70/500, Train Loss: 2.3122, Valid Loss: 0.2220
# RMSE: 0.4711
# {69}
# Epoch 71/500, Train Loss: 2.3036, Valid Loss: 0.2083
# RMSE: 0.4564
# {70}
# Epoch 72/500, Train Loss: 2.3310, Valid Loss: 0.2159
# RMSE: 0.4647
# {71}
# Epoch 73/500, Train Loss: 2.3166, Valid Loss: 0.2205
# RMSE: 0.4696
# {72}
# Epoch 74/500, Train Loss: 2.2976, Valid Loss: 0.2199
# RMSE: 0.4689
# {73}
# Epoch 75/500, Train Loss: 2.2559, Valid Loss: 0.2137
# RMSE: 0.4623
# {74}
# Epoch 76/500, Train Loss: 2.2385, Valid Loss: 0.2142
# RMSE: 0.4628
# {75}
# Epoch 77/500, Train Loss: 2.2143, Valid Loss: 0.2246
# RMSE: 0.4739
# {76}
# Epoch 78/500, Train Loss: 2.2254, Valid Loss: 0.2242
# RMSE: 0.4735
# {77}
# Epoch 79/500, Train Loss: 2.2141, Valid Loss: 0.2219
# RMSE: 0.4711
# {78}
# Epoch 80/500, Train Loss: 2.1972, Valid Loss: 0.2149
# RMSE: 0.4636
# {79}
# Epoch 81/500, Train Loss: 2.2005, Valid Loss: 0.2226
# RMSE: 0.4718
# {80}
# Epoch 82/500, Train Loss: 2.1980, Valid Loss: 0.2167
# RMSE: 0.4655
# {81}
# Epoch 83/500, Train Loss: 2.1589, Valid Loss: 0.2295
# RMSE: 0.4791
# {82}
# Epoch 84/500, Train Loss: 2.1638, Valid Loss: 0.2196
# RMSE: 0.4687
# {83}
# Epoch 85/500, Train Loss: 2.1514, Valid Loss: 0.2183
# RMSE: 0.4672
# {84}
# Epoch 86/500, Train Loss: 2.1362, Valid Loss: 0.2169
# RMSE: 0.4657
# {85}
# Epoch 87/500, Train Loss: 2.1296, Valid Loss: 0.2282
# RMSE: 0.4777
# {86}
# Epoch 88/500, Train Loss: 2.1649, Valid Loss: 0.2268
# RMSE: 0.4763
# {87}
# Epoch 89/500, Train Loss: 2.1480, Valid Loss: 0.2252
# RMSE: 0.4746
# {88}
# Epoch 90/500, Train Loss: 2.1185, Valid Loss: 0.2184
# RMSE: 0.4673
# {89}
# Epoch 91/500, Train Loss: 2.1206, Valid Loss: 0.2238
# RMSE: 0.4731
# {90}
# Epoch 92/500, Train Loss: 2.1037, Valid Loss: 0.2225
# RMSE: 0.4717
# {91}
# Epoch 93/500, Train Loss: 2.0900, Valid Loss: 0.2442
# RMSE: 0.4942
# {92}
# Epoch 94/500, Train Loss: 2.1298, Valid Loss: 0.2267
# RMSE: 0.4761
# {93}
# Epoch 95/500, Train Loss: 2.0728, Valid Loss: 0.2310
# RMSE: 0.4807
# {94}
# Epoch 96/500, Train Loss: 2.0872, Valid Loss: 0.2326
# RMSE: 0.4823
# {95}
# Epoch 97/500, Train Loss: 2.0586, Valid Loss: 0.2274
# RMSE: 0.4769
# {96}
# Epoch 98/500, Train Loss: 2.0583, Valid Loss: 0.2519
# RMSE: 0.5019
# {97}
# Epoch 99/500, Train Loss: 2.0561, Valid Loss: 0.2349
# RMSE: 0.4846
# {98}
# Epoch 100/500, Train Loss: 2.0477, Valid Loss: 0.2381
# RMSE: 0.4879
# {99}
# Epoch 101/500, Train Loss: 2.0815, Valid Loss: 0.2290
# RMSE: 0.4786
# {100}
# Epoch 102/500, Train Loss: 2.0780, Valid Loss: 0.2252
# RMSE: 0.4746
# {101}
# Epoch 103/500, Train Loss: 2.0313, Valid Loss: 0.2382
# RMSE: 0.4880
# {102}
# Epoch 104/500, Train Loss: 2.0207, Valid Loss: 0.2247
# RMSE: 0.4740
# {103}
# Epoch 105/500, Train Loss: 2.0330, Valid Loss: 0.2335
# RMSE: 0.4832
# {104}
# Epoch 106/500, Train Loss: 2.0682, Valid Loss: 0.2202
# RMSE: 0.4693
# {105}
# Epoch 107/500, Train Loss: 2.0436, Valid Loss: 0.2250
# RMSE: 0.4743
# {106}
# Epoch 108/500, Train Loss: 2.0215, Valid Loss: 0.2283
# RMSE: 0.4778
# {107}
# Epoch 109/500, Train Loss: 2.0271, Valid Loss: 0.2269
# RMSE: 0.4764
# {108}
# Epoch 110/500, Train Loss: 2.0228, Valid Loss: 0.2323
# RMSE: 0.4820
# {109}
# Epoch 111/500, Train Loss: 2.0564, Valid Loss: 0.2260
# RMSE: 0.4753
# {110}
# Epoch 112/500, Train Loss: 1.9908, Valid Loss: 0.2229
# RMSE: 0.4721
# {111}
# Epoch 113/500, Train Loss: 1.9694, Valid Loss: 0.2313
# RMSE: 0.4809
# {112}
# Epoch 114/500, Train Loss: 1.9810, Valid Loss: 0.2275
# RMSE: 0.4770
# {113}
# Epoch 115/500, Train Loss: 1.9762, Valid Loss: 0.2308
# RMSE: 0.4804
# {114}
# Epoch 116/500, Train Loss: 1.9772, Valid Loss: 0.2231
# RMSE: 0.4723
# {115}
# Epoch 117/500, Train Loss: 1.9495, Valid Loss: 0.2228
# RMSE: 0.4720
# {116}
# Epoch 118/500, Train Loss: 1.9696, Valid Loss: 0.2465
# RMSE: 0.4964
# {117}
# Epoch 119/500, Train Loss: 1.9714, Valid Loss: 0.2327
# RMSE: 0.4824
# {118}
# Epoch 120/500, Train Loss: 1.9559, Valid Loss: 0.2354
# RMSE: 0.4852
# {119}
# Epoch 121/500, Train Loss: 2.0161, Valid Loss: 0.2180
# RMSE: 0.4669
# {120}
# Epoch 122/500, Train Loss: 1.9844, Valid Loss: 0.2248
# RMSE: 0.4742
# {121}
# Epoch 123/500, Train Loss: 1.9768, Valid Loss: 0.2402
# RMSE: 0.4901
# {122}
# Epoch 124/500, Train Loss: 1.9637, Valid Loss: 0.2323
# RMSE: 0.4820
# {123}
# Epoch 125/500, Train Loss: 1.9430, Valid Loss: 0.2455
# RMSE: 0.4955
# {124}
# Epoch 126/500, Train Loss: 1.9857, Valid Loss: 0.2361
# RMSE: 0.4859
# {125}
# Epoch 127/500, Train Loss: 1.9230, Valid Loss: 0.2447
# RMSE: 0.4947
# {126}
# Epoch 128/500, Train Loss: 1.9153, Valid Loss: 0.2504
# RMSE: 0.5004
# {127}
# Epoch 129/500, Train Loss: 1.9111, Valid Loss: 0.2451
# RMSE: 0.4951
# {128}
# Epoch 130/500, Train Loss: 1.9160, Valid Loss: 0.2527
# RMSE: 0.5026
# {129}
# Epoch 131/500, Train Loss: 1.9304, Valid Loss: 0.2394
# RMSE: 0.4892
# {130}
# Epoch 132/500, Train Loss: 1.8983, Valid Loss: 0.2477
# RMSE: 0.4977
# {131}
# Epoch 133/500, Train Loss: 1.8900, Valid Loss: 0.2560
# RMSE: 0.5059
# {132}
# Epoch 134/500, Train Loss: 1.9142, Valid Loss: 0.2541
# RMSE: 0.5041
# {133}
# Epoch 135/500, Train Loss: 1.8828, Valid Loss: 0.2557
# RMSE: 0.5057
# {134}
# Epoch 136/500, Train Loss: 1.9125, Valid Loss: 0.2377
# RMSE: 0.4876
# {135}
# Epoch 137/500, Train Loss: 1.8834, Valid Loss: 0.2453
# RMSE: 0.4953
# {136}
# Epoch 138/500, Train Loss: 1.8906, Valid Loss: 0.2531
# RMSE: 0.5031
# {137}
# Epoch 139/500, Train Loss: 1.8907, Valid Loss: 0.2486
# RMSE: 0.4986
# {138}
# Epoch 140/500, Train Loss: 1.8914, Valid Loss: 0.2598
# RMSE: 0.5097
# {139}
# Epoch 141/500, Train Loss: 1.9288, Valid Loss: 0.2355
# RMSE: 0.4853
# {140}
# Epoch 142/500, Train Loss: 1.8949, Valid Loss: 0.2522
# RMSE: 0.5021
# {141}
# Epoch 143/500, Train Loss: 1.8954, Valid Loss: 0.2559
# RMSE: 0.5059
# {142}
# Epoch 144/500, Train Loss: 1.9117, Valid Loss: 0.2423
# RMSE: 0.4923
# {143}
# Epoch 145/500, Train Loss: 1.8941, Valid Loss: 0.2670
# RMSE: 0.5167
# {144}
# Epoch 146/500, Train Loss: 1.9418, Valid Loss: 0.2468
# RMSE: 0.4968
# {145}
# Epoch 147/500, Train Loss: 1.8560, Valid Loss: 0.2585
# RMSE: 0.5085
# {146}
# Epoch 148/500, Train Loss: 1.8545, Valid Loss: 0.2548
# RMSE: 0.5048
# {147}
# Epoch 149/500, Train Loss: 1.8453, Valid Loss: 0.2512
# RMSE: 0.5012
# {148}
# Epoch 150/500, Train Loss: 1.8425, Valid Loss: 0.2658
# RMSE: 0.5155
# {149}
# Epoch 151/500, Train Loss: 1.9032, Valid Loss: 0.2486
# RMSE: 0.4986
# {150}
# Epoch 152/500, Train Loss: 1.8474, Valid Loss: 0.2655
# RMSE: 0.5153
# {151}
# Epoch 153/500, Train Loss: 1.8369, Valid Loss: 0.2601
# RMSE: 0.5100
# {152}
# Epoch 154/500, Train Loss: 1.8120, Valid Loss: 0.2525
# RMSE: 0.5025
# {153}
# Epoch 155/500, Train Loss: 1.8324, Valid Loss: 0.2641
# RMSE: 0.5139
# {154}
# Epoch 156/500, Train Loss: 1.8876, Valid Loss: 0.2484
# RMSE: 0.4984
# {155}
# Epoch 157/500, Train Loss: 1.8487, Valid Loss: 0.2692
# RMSE: 0.5188
# {156}
# Epoch 158/500, Train Loss: 1.8203, Valid Loss: 0.2589
# RMSE: 0.5088
# {157}
# Epoch 159/500, Train Loss: 1.8128, Valid Loss: 0.2522
# RMSE: 0.5022
# {158}
# Epoch 160/500, Train Loss: 1.8510, Valid Loss: 0.2620
# RMSE: 0.5118
# {159}
# Epoch 161/500, Train Loss: 1.9013, Valid Loss: 0.2479
# RMSE: 0.4979
# {160}
# Epoch 162/500, Train Loss: 1.8457, Valid Loss: 0.2708
# RMSE: 0.5204
# {161}
# Epoch 163/500, Train Loss: 1.8201, Valid Loss: 0.2624
# RMSE: 0.5122
# {162}
# Epoch 164/500, Train Loss: 1.8084, Valid Loss: 0.2539
# RMSE: 0.5038
# {163}
# Epoch 165/500, Train Loss: 1.8183, Valid Loss: 0.2557
# RMSE: 0.5057
# {164}
# Epoch 166/500, Train Loss: 1.8647, Valid Loss: 0.2395
# RMSE: 0.4894
# {165}
# Epoch 167/500, Train Loss: 1.8132, Valid Loss: 0.2546
# RMSE: 0.5046
# {166}
# Epoch 168/500, Train Loss: 1.8066, Valid Loss: 0.2479
# RMSE: 0.4978
# {167}
# Epoch 169/500, Train Loss: 1.7977, Valid Loss: 0.2362
# RMSE: 0.4860
# {168}
# Epoch 170/500, Train Loss: 1.8229, Valid Loss: 0.2568
# RMSE: 0.5067
# {169}
# Epoch 171/500, Train Loss: 1.8786, Valid Loss: 0.2416
# RMSE: 0.4915
# {170}
# Epoch 172/500, Train Loss: 1.8056, Valid Loss: 0.2604
# RMSE: 0.5103
# {171}
# Epoch 173/500, Train Loss: 1.7841, Valid Loss: 0.2516
# RMSE: 0.5016
# {172}
# Epoch 174/500, Train Loss: 1.7891, Valid Loss: 0.2436
# RMSE: 0.4936
# {173}
# Epoch 175/500, Train Loss: 1.7970, Valid Loss: 0.2582
# RMSE: 0.5081
# {174}
# Epoch 176/500, Train Loss: 1.8442, Valid Loss: 0.2428
# RMSE: 0.4927
# {175}
# Epoch 177/500, Train Loss: 1.7830, Valid Loss: 0.2575
# RMSE: 0.5075
# {176}
# Epoch 178/500, Train Loss: 1.7753, Valid Loss: 0.2513
# RMSE: 0.5013
# {177}
# Epoch 179/500, Train Loss: 1.7860, Valid Loss: 0.2485
# RMSE: 0.4985
# {178}
# Epoch 180/500, Train Loss: 1.8012, Valid Loss: 0.2578
# RMSE: 0.5077
# {179}
# Epoch 181/500, Train Loss: 1.8240, Valid Loss: 0.2469
# RMSE: 0.4969
# {180}
# Epoch 182/500, Train Loss: 1.7743, Valid Loss: 0.2655
# RMSE: 0.5153
# {181}
# Epoch 183/500, Train Loss: 1.7828, Valid Loss: 0.2585
# RMSE: 0.5084
# {182}
# Epoch 184/500, Train Loss: 1.7636, Valid Loss: 0.2547
# RMSE: 0.5047
# {183}
# Epoch 185/500, Train Loss: 1.7851, Valid Loss: 0.2614
# RMSE: 0.5113
# {184}
# Epoch 186/500, Train Loss: 1.8201, Valid Loss: 0.2523
# RMSE: 0.5023
# {185}
# Epoch 187/500, Train Loss: 1.7810, Valid Loss: 0.2762
# RMSE: 0.5256
# {186}
# Epoch 188/500, Train Loss: 1.7774, Valid Loss: 0.2608
# RMSE: 0.5107
# {187}
# Epoch 189/500, Train Loss: 1.7507, Valid Loss: 0.2556
# RMSE: 0.5056
# {188}
# Epoch 190/500, Train Loss: 1.7815, Valid Loss: 0.2631
# RMSE: 0.5129
# {189}
# Epoch 191/500, Train Loss: 1.8387, Valid Loss: 0.2523
# RMSE: 0.5023
# {190}
# Epoch 192/500, Train Loss: 1.8012, Valid Loss: 0.2771
# RMSE: 0.5264
# {191}
# Epoch 193/500, Train Loss: 1.7789, Valid Loss: 0.2588
# RMSE: 0.5087
# {192}
# Epoch 194/500, Train Loss: 1.7688, Valid Loss: 0.2519
# RMSE: 0.5018
# {193}
# Epoch 195/500, Train Loss: 1.7907, Valid Loss: 0.2565
# RMSE: 0.5064
# {194}
# Epoch 196/500, Train Loss: 1.8523, Valid Loss: 0.2399
# RMSE: 0.4898
# {195}
# Epoch 197/500, Train Loss: 1.7814, Valid Loss: 0.2667
# RMSE: 0.5164
# {196}
# Epoch 198/500, Train Loss: 1.7512, Valid Loss: 0.2526
# RMSE: 0.5026
# {197}
# Epoch 199/500, Train Loss: 1.7453, Valid Loss: 0.2459
# RMSE: 0.4958
# {198}
# Epoch 200/500, Train Loss: 1.7777, Valid Loss: 0.2552
# RMSE: 0.5051
# {199}
# Epoch 201/500, Train Loss: 1.8307, Valid Loss: 0.2417
# RMSE: 0.4916
# {200}
# Epoch 202/500, Train Loss: 1.7722, Valid Loss: 0.2631
# RMSE: 0.5129
# {201}
# Epoch 203/500, Train Loss: 1.7405, Valid Loss: 0.2487
# RMSE: 0.4987
# {202}
# Epoch 204/500, Train Loss: 1.7466, Valid Loss: 0.2451
# RMSE: 0.4950
# {203}
# Epoch 205/500, Train Loss: 1.7714, Valid Loss: 0.2569
# RMSE: 0.5069
# {204}
# Epoch 206/500, Train Loss: 1.8142, Valid Loss: 0.2444
# RMSE: 0.4944
# {205}
# Epoch 207/500, Train Loss: 1.7577, Valid Loss: 0.2639
# RMSE: 0.5137
# {206}
# Epoch 208/500, Train Loss: 1.7424, Valid Loss: 0.2482
# RMSE: 0.4982
# {207}
# Epoch 209/500, Train Loss: 1.7474, Valid Loss: 0.2467
# RMSE: 0.4967
# {208}
# Epoch 210/500, Train Loss: 1.7672, Valid Loss: 0.2541
# RMSE: 0.5041
# {209}
# Epoch 211/500, Train Loss: 1.7941, Valid Loss: 0.2460
# RMSE: 0.4959
# {210}
# Epoch 212/500, Train Loss: 1.7475, Valid Loss: 0.2658
# RMSE: 0.5155
# {211}
# Epoch 213/500, Train Loss: 1.7433, Valid Loss: 0.2509
# RMSE: 0.5009
# {212}
# Epoch 214/500, Train Loss: 1.7304, Valid Loss: 0.2490
# RMSE: 0.4990
# {213}
# Epoch 215/500, Train Loss: 1.7519, Valid Loss: 0.2526
# RMSE: 0.5025
# {214}
# Epoch 216/500, Train Loss: 1.7845, Valid Loss: 0.2460
# RMSE: 0.4960
# {215}
# Epoch 217/500, Train Loss: 1.7450, Valid Loss: 0.2658
# RMSE: 0.5156
# {216}
# Epoch 218/500, Train Loss: 1.7337, Valid Loss: 0.2530
# RMSE: 0.5030
# {217}
# Epoch 219/500, Train Loss: 1.7261, Valid Loss: 0.2493
# RMSE: 0.4993
# {218}
# Epoch 220/500, Train Loss: 1.7501, Valid Loss: 0.2533
# RMSE: 0.5033
# {219}
# Epoch 221/500, Train Loss: 1.7841, Valid Loss: 0.2469
# RMSE: 0.4969
# {220}
# Epoch 222/500, Train Loss: 1.7407, Valid Loss: 0.2666
# RMSE: 0.5163
# {221}
# Epoch 223/500, Train Loss: 1.7374, Valid Loss: 0.2518
# RMSE: 0.5018
# {222}
# Epoch 224/500, Train Loss: 1.7215, Valid Loss: 0.2487
# RMSE: 0.4987
# {223}
# Epoch 225/500, Train Loss: 1.7552, Valid Loss: 0.2520
# RMSE: 0.5020
# {224}
# Epoch 226/500, Train Loss: 1.7913, Valid Loss: 0.2467
# RMSE: 0.4967
# {225}
# Epoch 227/500, Train Loss: 1.7520, Valid Loss: 0.2643
# RMSE: 0.5141
# {226}
# Epoch 228/500, Train Loss: 1.7312, Valid Loss: 0.2447
# RMSE: 0.4947
# {227}
# Epoch 229/500, Train Loss: 1.7172, Valid Loss: 0.2419
# RMSE: 0.4918
# {228}
# Epoch 230/500, Train Loss: 1.7632, Valid Loss: 0.2394
# RMSE: 0.4893
# {229}
# Epoch 231/500, Train Loss: 1.8214, Valid Loss: 0.2383
# RMSE: 0.4881
# {230}
# Epoch 232/500, Train Loss: 1.7765, Valid Loss: 0.2522
# RMSE: 0.5022
# {231}
# Epoch 233/500, Train Loss: 1.7131, Valid Loss: 0.2374
# RMSE: 0.4872
# {232}
# Epoch 234/500, Train Loss: 1.7364, Valid Loss: 0.2309
# RMSE: 0.4805
# {233}
# Epoch 235/500, Train Loss: 1.7993, Valid Loss: 0.2273
# RMSE: 0.4767
# {234}
# Epoch 236/500, Train Loss: 1.8648, Valid Loss: 0.2255
# RMSE: 0.4749
# {235}
# Epoch 237/500, Train Loss: 1.7558, Valid Loss: 0.2439
# RMSE: 0.4938
# {236}
# Epoch 238/500, Train Loss: 1.7120, Valid Loss: 0.2322
# RMSE: 0.4819
# {237}
# Epoch 239/500, Train Loss: 1.7324, Valid Loss: 0.2259
# RMSE: 0.4753
# {238}
# Epoch 240/500, Train Loss: 1.7825, Valid Loss: 0.2289
# RMSE: 0.4784
# {239}
# Epoch 241/500, Train Loss: 1.7961, Valid Loss: 0.2286
# RMSE: 0.4781
# {240}
# Epoch 242/500, Train Loss: 1.7207, Valid Loss: 0.2437
# RMSE: 0.4937
# {241}
# Epoch 243/500, Train Loss: 1.6924, Valid Loss: 0.2394
# RMSE: 0.4893
# {242}
# Epoch 244/500, Train Loss: 1.7113, Valid Loss: 0.2359
# RMSE: 0.4856
# {243}
# Epoch 245/500, Train Loss: 1.7358, Valid Loss: 0.2401
# RMSE: 0.4900
# {244}
# Epoch 246/500, Train Loss: 1.7471, Valid Loss: 0.2360
# RMSE: 0.4858
# {245}
# Epoch 247/500, Train Loss: 1.7018, Valid Loss: 0.2530
# RMSE: 0.5030
# {246}
# Epoch 248/500, Train Loss: 1.6853, Valid Loss: 0.2454
# RMSE: 0.4954
# {247}
# Epoch 249/500, Train Loss: 1.6913, Valid Loss: 0.2407
# RMSE: 0.4906
# {248}
# Epoch 250/500, Train Loss: 1.7107, Valid Loss: 0.2423
# RMSE: 0.4923
# {249}
# Epoch 251/500, Train Loss: 1.7253, Valid Loss: 0.2378
# RMSE: 0.4877
# {250}
# Epoch 252/500, Train Loss: 1.6975, Valid Loss: 0.2539
# RMSE: 0.5039
# {251}
# Epoch 253/500, Train Loss: 1.6849, Valid Loss: 0.2445
# RMSE: 0.4944
# {252}
# Epoch 254/500, Train Loss: 1.6854, Valid Loss: 0.2394
# RMSE: 0.4893
# {253}
# Epoch 255/500, Train Loss: 1.7066, Valid Loss: 0.2390
# RMSE: 0.4889
# {254}
# Epoch 256/500, Train Loss: 1.7222, Valid Loss: 0.2357
# RMSE: 0.4855
# {255}
# Epoch 257/500, Train Loss: 1.6984, Valid Loss: 0.2492
# RMSE: 0.4992
# {256}
# Epoch 258/500, Train Loss: 1.6830, Valid Loss: 0.2388
# RMSE: 0.4887
# {257}
# Epoch 259/500, Train Loss: 1.6898, Valid Loss: 0.2342
# RMSE: 0.4840
# {258}
# Epoch 260/500, Train Loss: 1.7101, Valid Loss: 0.2315
# RMSE: 0.4811
# {259}
# Epoch 261/500, Train Loss: 1.7290, Valid Loss: 0.2317
# RMSE: 0.4814
# {260}
# Epoch 262/500, Train Loss: 1.7008, Valid Loss: 0.2426
# RMSE: 0.4926
# {261}
# Epoch 263/500, Train Loss: 1.6924, Valid Loss: 0.2336
# RMSE: 0.4833
# {262}
# Epoch 264/500, Train Loss: 1.6960, Valid Loss: 0.2316
# RMSE: 0.4812
# {263}
# Epoch 265/500, Train Loss: 1.7166, Valid Loss: 0.2259
# RMSE: 0.4752
# {264}
# Epoch 266/500, Train Loss: 1.7447, Valid Loss: 0.2304
# RMSE: 0.4800
# {265}
# Epoch 267/500, Train Loss: 1.7077, Valid Loss: 0.2411
# RMSE: 0.4910
# {266}
# Epoch 268/500, Train Loss: 1.6927, Valid Loss: 0.2340
# RMSE: 0.4838
# {267}
# Epoch 269/500, Train Loss: 1.6791, Valid Loss: 0.2314
# RMSE: 0.4810
# {268}
# Epoch 270/500, Train Loss: 1.7172, Valid Loss: 0.2258
# RMSE: 0.4752
# {269}
# Epoch 271/500, Train Loss: 1.7829, Valid Loss: 0.2315
# RMSE: 0.4811
# {270}
# Epoch 272/500, Train Loss: 1.7160, Valid Loss: 0.2482
# RMSE: 0.4982
# {271}
# Epoch 273/500, Train Loss: 1.6918, Valid Loss: 0.2327
# RMSE: 0.4824
# {272}
# Epoch 274/500, Train Loss: 1.6865, Valid Loss: 0.2256
# RMSE: 0.4750
# {273}
# Epoch 275/500, Train Loss: 1.7162, Valid Loss: 0.2235
# RMSE: 0.4727
# {274}
# Epoch 276/500, Train Loss: 1.7816, Valid Loss: 0.2234
# RMSE: 0.4726
# {275}
# Epoch 277/500, Train Loss: 1.7034, Valid Loss: 0.2375
# RMSE: 0.4873
# {276}
# Epoch 278/500, Train Loss: 1.6802, Valid Loss: 0.2260
# RMSE: 0.4754
# {277}
# Epoch 279/500, Train Loss: 1.6852, Valid Loss: 0.2243
# RMSE: 0.4736
# {278}
# Epoch 280/500, Train Loss: 1.7231, Valid Loss: 0.2146
# RMSE: 0.4632
# {279}
# Epoch 281/500, Train Loss: 1.7668, Valid Loss: 0.2211
# RMSE: 0.4702
# {280}
# Epoch 282/500, Train Loss: 1.6803, Valid Loss: 0.2322
# RMSE: 0.4819
# {281}
# Epoch 283/500, Train Loss: 1.6641, Valid Loss: 0.2264
# RMSE: 0.4759
# {282}
# Epoch 284/500, Train Loss: 1.6747, Valid Loss: 0.2266
# RMSE: 0.4760
# {283}
# Epoch 285/500, Train Loss: 1.7040, Valid Loss: 0.2190
# RMSE: 0.4680
# {284}
# Epoch 286/500, Train Loss: 1.7182, Valid Loss: 0.2249
# RMSE: 0.4742
# {285}
# Epoch 287/500, Train Loss: 1.6585, Valid Loss: 0.2354
# RMSE: 0.4852
# {286}
# Epoch 288/500, Train Loss: 1.6495, Valid Loss: 0.2306
# RMSE: 0.4802
# {287}
# Epoch 289/500, Train Loss: 1.6498, Valid Loss: 0.2307
# RMSE: 0.4803
# {288}
# Epoch 290/500, Train Loss: 1.6749, Valid Loss: 0.2265
# RMSE: 0.4759
# {289}
# Epoch 291/500, Train Loss: 1.6860, Valid Loss: 0.2309
# RMSE: 0.4805
# {290}
# Epoch 292/500, Train Loss: 1.6505, Valid Loss: 0.2407
# RMSE: 0.4907
# {291}
# Epoch 293/500, Train Loss: 1.6434, Valid Loss: 0.2349
# RMSE: 0.4847
# {292}
# Epoch 294/500, Train Loss: 1.6356, Valid Loss: 0.2342
# RMSE: 0.4840
# {293}
# Epoch 295/500, Train Loss: 1.6619, Valid Loss: 0.2319
# RMSE: 0.4815
# {294}
# Epoch 296/500, Train Loss: 1.6757, Valid Loss: 0.2367
# RMSE: 0.4865
# {295}
# Epoch 297/500, Train Loss: 1.6457, Valid Loss: 0.2464
# RMSE: 0.4964
# {296}
# Epoch 298/500, Train Loss: 1.6420, Valid Loss: 0.2380
# RMSE: 0.4878
# {297}
# Epoch 299/500, Train Loss: 1.6269, Valid Loss: 0.2365
# RMSE: 0.4863
# {298}
# Epoch 300/500, Train Loss: 1.6534, Valid Loss: 0.2363
# RMSE: 0.4861
# {299}
# Epoch 301/500, Train Loss: 1.6749, Valid Loss: 0.2415
# RMSE: 0.4914
# {300}
# Epoch 302/500, Train Loss: 1.6410, Valid Loss: 0.2511
# RMSE: 0.5011
# {301}
# Epoch 303/500, Train Loss: 1.6407, Valid Loss: 0.2395
# RMSE: 0.4893
# {302}
# Epoch 304/500, Train Loss: 1.6269, Valid Loss: 0.2389
# RMSE: 0.4888
# {303}
# Epoch 305/500, Train Loss: 1.6485, Valid Loss: 0.2393
# RMSE: 0.4891
# {304}
# Epoch 306/500, Train Loss: 1.6794, Valid Loss: 0.2432
# RMSE: 0.4932
# {305}
# Epoch 307/500, Train Loss: 1.6470, Valid Loss: 0.2542
# RMSE: 0.5042
# {306}
# Epoch 308/500, Train Loss: 1.6490, Valid Loss: 0.2395
# RMSE: 0.4894
# {307}
# Epoch 309/500, Train Loss: 1.6448, Valid Loss: 0.2374
# RMSE: 0.4873
# {308}
# Epoch 310/500, Train Loss: 1.6511, Valid Loss: 0.2398
# RMSE: 0.4897
# {309}
# Epoch 311/500, Train Loss: 1.6718, Valid Loss: 0.2410
# RMSE: 0.4910
# {310}
# Epoch 312/500, Train Loss: 1.6371, Valid Loss: 0.2539
# RMSE: 0.5038
# {311}
# Epoch 313/500, Train Loss: 1.6338, Valid Loss: 0.2378
# RMSE: 0.4877
# {312}
# Epoch 314/500, Train Loss: 1.6335, Valid Loss: 0.2394
# RMSE: 0.4893
# {313}
# Epoch 315/500, Train Loss: 1.6454, Valid Loss: 0.2399
# RMSE: 0.4898
# {314}
# Epoch 316/500, Train Loss: 1.6714, Valid Loss: 0.2404
# RMSE: 0.4903
# {315}
# Epoch 317/500, Train Loss: 1.6301, Valid Loss: 0.2534
# RMSE: 0.5034
# {316}
# Epoch 318/500, Train Loss: 1.6282, Valid Loss: 0.2359
# RMSE: 0.4856
# {317}
# Epoch 319/500, Train Loss: 1.6231, Valid Loss: 0.2381
# RMSE: 0.4880
# {318}
# Epoch 320/500, Train Loss: 1.6429, Valid Loss: 0.2402
# RMSE: 0.4901
# {319}
# Epoch 321/500, Train Loss: 1.6625, Valid Loss: 0.2377
# RMSE: 0.4875
# {320}
# Epoch 322/500, Train Loss: 1.6215, Valid Loss: 0.2503
# RMSE: 0.5003
# {321}
# Epoch 323/500, Train Loss: 1.6176, Valid Loss: 0.2357
# RMSE: 0.4855
# {322}
# Epoch 324/500, Train Loss: 1.6357, Valid Loss: 0.2391
# RMSE: 0.4889
# {323}
# Epoch 325/500, Train Loss: 1.6581, Valid Loss: 0.2394
# RMSE: 0.4892
# {324}
# Epoch 326/500, Train Loss: 1.6719, Valid Loss: 0.2347
# RMSE: 0.4845
# {325}
# Epoch 327/500, Train Loss: 1.6331, Valid Loss: 0.2412
# RMSE: 0.4911
# {326}
# Epoch 328/500, Train Loss: 1.6402, Valid Loss: 0.2313
# RMSE: 0.4809
# {327}
# Epoch 329/500, Train Loss: 1.6713, Valid Loss: 0.2365
# RMSE: 0.4863
# {328}
# Epoch 330/500, Train Loss: 1.6905, Valid Loss: 0.2412
# RMSE: 0.4911
# {329}
# Epoch 331/500, Train Loss: 1.6973, Valid Loss: 0.2393
# RMSE: 0.4892
# {330}
# Epoch 332/500, Train Loss: 1.6580, Valid Loss: 0.2462
# RMSE: 0.4962
# {331}
# Epoch 333/500, Train Loss: 1.6887, Valid Loss: 0.2313
# RMSE: 0.4809
# {332}
# Epoch 334/500, Train Loss: 1.6481, Valid Loss: 0.2338
# RMSE: 0.4836
# {333}
# Epoch 335/500, Train Loss: 1.6534, Valid Loss: 0.2339
# RMSE: 0.4836
# {334}
# Epoch 336/500, Train Loss: 1.6776, Valid Loss: 0.2358
# RMSE: 0.4856
# {335}
# Epoch 337/500, Train Loss: 1.6531, Valid Loss: 0.2417
# RMSE: 0.4916
# {336}
# Epoch 338/500, Train Loss: 1.6369, Valid Loss: 0.2258
# RMSE: 0.4752
# {337}
# Epoch 339/500, Train Loss: 1.6173, Valid Loss: 0.2257
# RMSE: 0.4751
# {338}
# Epoch 340/500, Train Loss: 1.6503, Valid Loss: 0.2177
# RMSE: 0.4666
# {339}
# Epoch 341/500, Train Loss: 1.7087, Valid Loss: 0.2240
# RMSE: 0.4733
# {340}
# Epoch 342/500, Train Loss: 1.6441, Valid Loss: 0.2301
# RMSE: 0.4797
# {341}
# Epoch 343/500, Train Loss: 1.6337, Valid Loss: 0.2196
# RMSE: 0.4686
# {342}
# Epoch 344/500, Train Loss: 1.6249, Valid Loss: 0.2194
# RMSE: 0.4684
# {343}
# Epoch 345/500, Train Loss: 1.6461, Valid Loss: 0.2153
# RMSE: 0.4641
# {344}
# Epoch 346/500, Train Loss: 1.6692, Valid Loss: 0.2242
# RMSE: 0.4735
# {345}
# Epoch 347/500, Train Loss: 1.6180, Valid Loss: 0.2304
# RMSE: 0.4800
# {346}
# Epoch 348/500, Train Loss: 1.6172, Valid Loss: 0.2224
# RMSE: 0.4716
# {347}
# Epoch 349/500, Train Loss: 1.6201, Valid Loss: 0.2235
# RMSE: 0.4728
# {348}
# Epoch 350/500, Train Loss: 1.6264, Valid Loss: 0.2239
# RMSE: 0.4732
# {349}
# Epoch 351/500, Train Loss: 1.6434, Valid Loss: 0.2271
# RMSE: 0.4765
# {350}
# Epoch 352/500, Train Loss: 1.6064, Valid Loss: 0.2357
# RMSE: 0.4855
# {351}
# Epoch 353/500, Train Loss: 1.6045, Valid Loss: 0.2266
# RMSE: 0.4760
# {352}
# Epoch 354/500, Train Loss: 1.6174, Valid Loss: 0.2284
# RMSE: 0.4779
# {353}
# Epoch 355/500, Train Loss: 1.6179, Valid Loss: 0.2284
# RMSE: 0.4780
# {354}
# Epoch 356/500, Train Loss: 1.6336, Valid Loss: 0.2291
# RMSE: 0.4786
# {355}
# Epoch 357/500, Train Loss: 1.5973, Valid Loss: 0.2383
# RMSE: 0.4881
# {356}
# Epoch 358/500, Train Loss: 1.5972, Valid Loss: 0.2292
# RMSE: 0.4788
# {357}
# Epoch 359/500, Train Loss: 1.6150, Valid Loss: 0.2298
# RMSE: 0.4793
# {358}
# Epoch 360/500, Train Loss: 1.6125, Valid Loss: 0.2281
# RMSE: 0.4776
# {359}
# Epoch 361/500, Train Loss: 1.6273, Valid Loss: 0.2292
# RMSE: 0.4787
# {360}
# Epoch 362/500, Train Loss: 1.5877, Valid Loss: 0.2382
# RMSE: 0.4880
# {361}
# Epoch 363/500, Train Loss: 1.5881, Valid Loss: 0.2304
# RMSE: 0.4800
# {362}
# Epoch 364/500, Train Loss: 1.5927, Valid Loss: 0.2304
# RMSE: 0.4800
# {363}
# Epoch 365/500, Train Loss: 1.5936, Valid Loss: 0.2305
# RMSE: 0.4801
# {364}
# Epoch 366/500, Train Loss: 1.6037, Valid Loss: 0.2317
# RMSE: 0.4813
# {365}
# Epoch 367/500, Train Loss: 1.5768, Valid Loss: 0.2378
# RMSE: 0.4877
# {366}
# Epoch 368/500, Train Loss: 1.5722, Valid Loss: 0.2304
# RMSE: 0.4800
# {367}
# Epoch 369/500, Train Loss: 1.5722, Valid Loss: 0.2304
# RMSE: 0.4800
# {368}
# Epoch 370/500, Train Loss: 1.5797, Valid Loss: 0.2327
# RMSE: 0.4824
# {369}
# Epoch 371/500, Train Loss: 1.5845, Valid Loss: 0.2328
# RMSE: 0.4825
# {370}
# Epoch 372/500, Train Loss: 1.5692, Valid Loss: 0.2368
# RMSE: 0.4867
# {371}
# Epoch 373/500, Train Loss: 1.5611, Valid Loss: 0.2288
# RMSE: 0.4784
# {372}
# Epoch 374/500, Train Loss: 1.5686, Valid Loss: 0.2302
# RMSE: 0.4798
# {373}
# Epoch 375/500, Train Loss: 1.5774, Valid Loss: 0.2324
# RMSE: 0.4821
# {374}
# Epoch 376/500, Train Loss: 1.5866, Valid Loss: 0.2320
# RMSE: 0.4817
# {375}
# Epoch 377/500, Train Loss: 1.5706, Valid Loss: 0.2351
# RMSE: 0.4849
# {376}
# Epoch 378/500, Train Loss: 1.5663, Valid Loss: 0.2278
# RMSE: 0.4773
# {377}
# Epoch 379/500, Train Loss: 1.5729, Valid Loss: 0.2322
# RMSE: 0.4819
# {378}
# Epoch 380/500, Train Loss: 1.5796, Valid Loss: 0.2307
# RMSE: 0.4803
# {379}
# Epoch 381/500, Train Loss: 1.5834, Valid Loss: 0.2349
# RMSE: 0.4846
# {380}
# Epoch 382/500, Train Loss: 1.5685, Valid Loss: 0.2341
# RMSE: 0.4838
# {381}
# Epoch 383/500, Train Loss: 1.5684, Valid Loss: 0.2292
# RMSE: 0.4788
# {382}
# Epoch 384/500, Train Loss: 1.5792, Valid Loss: 0.2315
# RMSE: 0.4812
# {383}
# Epoch 385/500, Train Loss: 1.5843, Valid Loss: 0.2287
# RMSE: 0.4783
# {384}
# Epoch 386/500, Train Loss: 1.5906, Valid Loss: 0.2359
# RMSE: 0.4857
# {385}
# Epoch 387/500, Train Loss: 1.5675, Valid Loss: 0.2340
# RMSE: 0.4838
# {386}
# Epoch 388/500, Train Loss: 1.5616, Valid Loss: 0.2306
# RMSE: 0.4802
# {387}
# Epoch 389/500, Train Loss: 1.5673, Valid Loss: 0.2304
# RMSE: 0.4800
# {388}
# Epoch 390/500, Train Loss: 1.5692, Valid Loss: 0.2332
# RMSE: 0.4829
# {389}
# Epoch 391/500, Train Loss: 1.5889, Valid Loss: 0.2374
# RMSE: 0.4873
# {390}
# Epoch 392/500, Train Loss: 1.5649, Valid Loss: 0.2360
# RMSE: 0.4858
# {391}
# Epoch 393/500, Train Loss: 1.5744, Valid Loss: 0.2305
# RMSE: 0.4801
# {392}
# Epoch 394/500, Train Loss: 1.5690, Valid Loss: 0.2303
# RMSE: 0.4799
# {393}
# Epoch 395/500, Train Loss: 1.5688, Valid Loss: 0.2346
# RMSE: 0.4844
# {394}
# Epoch 396/500, Train Loss: 1.5822, Valid Loss: 0.2367
# RMSE: 0.4865
# {395}
# Epoch 397/500, Train Loss: 1.5605, Valid Loss: 0.2350
# RMSE: 0.4847
# {396}
# Epoch 398/500, Train Loss: 1.5659, Valid Loss: 0.2268
# RMSE: 0.4763
# {397}
# Epoch 399/500, Train Loss: 1.5575, Valid Loss: 0.2299
# RMSE: 0.4795
# {398}
# Epoch 400/500, Train Loss: 1.5624, Valid Loss: 0.2329
# RMSE: 0.4826
# {399}
# Epoch 401/500, Train Loss: 1.5725, Valid Loss: 0.2337
# RMSE: 0.4834
# {400}
# Epoch 402/500, Train Loss: 1.5564, Valid Loss: 0.2333
# RMSE: 0.4830
# {401}
# Epoch 403/500, Train Loss: 1.5594, Valid Loss: 0.2239
# RMSE: 0.4732
# {402}
# Epoch 404/500, Train Loss: 1.5553, Valid Loss: 0.2288
# RMSE: 0.4783
# {403}
# Epoch 405/500, Train Loss: 1.5583, Valid Loss: 0.2284
# RMSE: 0.4779
# {404}
# Epoch 406/500, Train Loss: 1.5675, Valid Loss: 0.2332
# RMSE: 0.4829
# {405}
# Epoch 407/500, Train Loss: 1.5482, Valid Loss: 0.2319
# RMSE: 0.4815
# {406}
# Epoch 408/500, Train Loss: 1.5543, Valid Loss: 0.2254
# RMSE: 0.4748
# {407}
# Epoch 409/500, Train Loss: 1.5624, Valid Loss: 0.2310
# RMSE: 0.4806
# {408}
# Epoch 410/500, Train Loss: 1.5570, Valid Loss: 0.2269
# RMSE: 0.4764
# {409}
# Epoch 411/500, Train Loss: 1.5634, Valid Loss: 0.2364
# RMSE: 0.4862
# {410}
# Epoch 412/500, Train Loss: 1.5450, Valid Loss: 0.2321
# RMSE: 0.4818
# {411}
# Epoch 413/500, Train Loss: 1.5599, Valid Loss: 0.2318
# RMSE: 0.4815
# {412}
# Epoch 414/500, Train Loss: 1.5720, Valid Loss: 0.2309
# RMSE: 0.4805
# {413}
# Epoch 415/500, Train Loss: 1.5625, Valid Loss: 0.2275
# RMSE: 0.4770
# {414}
# Epoch 416/500, Train Loss: 1.5732, Valid Loss: 0.2342
# RMSE: 0.4839
# {415}
# Epoch 417/500, Train Loss: 1.5384, Valid Loss: 0.2322
# RMSE: 0.4819
# {416}
# Epoch 418/500, Train Loss: 1.5507, Valid Loss: 0.2328
# RMSE: 0.4825
# {417}
# Epoch 419/500, Train Loss: 1.5594, Valid Loss: 0.2304
# RMSE: 0.4800
# {418}
# Epoch 420/500, Train Loss: 1.5569, Valid Loss: 0.2341
# RMSE: 0.4838
# {419}
# Epoch 421/500, Train Loss: 1.5608, Valid Loss: 0.2344
# RMSE: 0.4842
# {420}
# Epoch 422/500, Train Loss: 1.5440, Valid Loss: 0.2356
# RMSE: 0.4854
# {421}
# Epoch 423/500, Train Loss: 1.5677, Valid Loss: 0.2308
# RMSE: 0.4804
# {422}
# Epoch 424/500, Train Loss: 1.5695, Valid Loss: 0.2300
# RMSE: 0.4796
# {423}
# Epoch 425/500, Train Loss: 1.5613, Valid Loss: 0.2378
# RMSE: 0.4876
# {424}
# Epoch 426/500, Train Loss: 1.5481, Valid Loss: 0.2340
# RMSE: 0.4838
# {425}
# Epoch 427/500, Train Loss: 1.5386, Valid Loss: 0.2356
# RMSE: 0.4854
# {426}
# Epoch 428/500, Train Loss: 1.5391, Valid Loss: 0.2291
# RMSE: 0.4786
# {427}
# Epoch 429/500, Train Loss: 1.5416, Valid Loss: 0.2306
# RMSE: 0.4802
# {428}
# Epoch 430/500, Train Loss: 1.5428, Valid Loss: 0.2369
# RMSE: 0.4867
# {429}
# Epoch 431/500, Train Loss: 1.5534, Valid Loss: 0.2343
# RMSE: 0.4840
# {430}
# Epoch 432/500, Train Loss: 1.5420, Valid Loss: 0.2365
# RMSE: 0.4863
# {431}
# Epoch 433/500, Train Loss: 1.5473, Valid Loss: 0.2323
# RMSE: 0.4819
# {432}
# Epoch 434/500, Train Loss: 1.5430, Valid Loss: 0.2395
# RMSE: 0.4894
# {433}
# Epoch 435/500, Train Loss: 1.5342, Valid Loss: 0.2387
# RMSE: 0.4886
# {434}
# Epoch 436/500, Train Loss: 1.5355, Valid Loss: 0.2378
# RMSE: 0.4877
# {435}
# Epoch 437/500, Train Loss: 1.5232, Valid Loss: 0.2363
# RMSE: 0.4861
# {436}
# Epoch 438/500, Train Loss: 1.5325, Valid Loss: 0.2346
# RMSE: 0.4843
# {437}
# Epoch 439/500, Train Loss: 1.5240, Valid Loss: 0.2387
# RMSE: 0.4886
# {438}
# Epoch 440/500, Train Loss: 1.5225, Valid Loss: 0.2380
# RMSE: 0.4879
# {439}
# Epoch 441/500, Train Loss: 1.5177, Valid Loss: 0.2373
# RMSE: 0.4871
# {440}
# Epoch 442/500, Train Loss: 1.5175, Valid Loss: 0.2328
# RMSE: 0.4825
# {441}
# Epoch 443/500, Train Loss: 1.5181, Valid Loss: 0.2310
# RMSE: 0.4806
# {442}
# Epoch 444/500, Train Loss: 1.5209, Valid Loss: 0.2310
# RMSE: 0.4806
# {443}
# Epoch 445/500, Train Loss: 1.5254, Valid Loss: 0.2409
# RMSE: 0.4908
# {444}
# Epoch 446/500, Train Loss: 1.5589, Valid Loss: 0.2370
# RMSE: 0.4868
# {445}
# Epoch 447/500, Train Loss: 1.5225, Valid Loss: 0.2381
# RMSE: 0.4880
# {446}
# Epoch 448/500, Train Loss: 1.5224, Valid Loss: 0.2286
# RMSE: 0.4781
# {447}
# Epoch 449/500, Train Loss: 1.5172, Valid Loss: 0.2350
# RMSE: 0.4847
# {448}
# Epoch 450/500, Train Loss: 1.5181, Valid Loss: 0.2366
# RMSE: 0.4864
# {449}
# Epoch 451/500, Train Loss: 1.5373, Valid Loss: 0.2372
# RMSE: 0.4871
# {450}
# Epoch 452/500, Train Loss: 1.5138, Valid Loss: 0.2358
# RMSE: 0.4856
# {451}
# Epoch 453/500, Train Loss: 1.5185, Valid Loss: 0.2329
# RMSE: 0.4826
# {452}
# Epoch 454/500, Train Loss: 1.5170, Valid Loss: 0.2363
# RMSE: 0.4861
# {453}
# Epoch 455/500, Train Loss: 1.5151, Valid Loss: 0.2382
# RMSE: 0.4880
# {454}
# Epoch 456/500, Train Loss: 1.5404, Valid Loss: 0.2394
# RMSE: 0.4893
# {455}
# Epoch 457/500, Train Loss: 1.5147, Valid Loss: 0.2376
# RMSE: 0.4875
# {456}
# Epoch 458/500, Train Loss: 1.5237, Valid Loss: 0.2352
# RMSE: 0.4850
# {457}
# Epoch 459/500, Train Loss: 1.5139, Valid Loss: 0.2369
# RMSE: 0.4867
# {458}
# Epoch 460/500, Train Loss: 1.5118, Valid Loss: 0.2408
# RMSE: 0.4907
# {459}
# Epoch 461/500, Train Loss: 1.5260, Valid Loss: 0.2412
# RMSE: 0.4911
# {460}
# Epoch 462/500, Train Loss: 1.5050, Valid Loss: 0.2388
# RMSE: 0.4886
# {461}
# Epoch 463/500, Train Loss: 1.5074, Valid Loss: 0.2365
# RMSE: 0.4863
# {462}
# Epoch 464/500, Train Loss: 1.5021, Valid Loss: 0.2360
# RMSE: 0.4858
# {463}
# Epoch 465/500, Train Loss: 1.5125, Valid Loss: 0.2433
# RMSE: 0.4932
# {464}
# Epoch 466/500, Train Loss: 1.5206, Valid Loss: 0.2408
# RMSE: 0.4907
# {465}
# Epoch 467/500, Train Loss: 1.5039, Valid Loss: 0.2378
# RMSE: 0.4877
# {466}
# Epoch 468/500, Train Loss: 1.5056, Valid Loss: 0.2377
# RMSE: 0.4875
# {467}
# Epoch 469/500, Train Loss: 1.5185, Valid Loss: 0.2414
# RMSE: 0.4913
# {468}
# Epoch 470/500, Train Loss: 1.5156, Valid Loss: 0.2428
# RMSE: 0.4928
# {469}
# Epoch 471/500, Train Loss: 1.5140, Valid Loss: 0.2402
# RMSE: 0.4901
# {470}
# Epoch 472/500, Train Loss: 1.5025, Valid Loss: 0.2354
# RMSE: 0.4852
# {471}
# Epoch 473/500, Train Loss: 1.5058, Valid Loss: 0.2364
# RMSE: 0.4862
# {472}
# Epoch 474/500, Train Loss: 1.5092, Valid Loss: 0.2383
# RMSE: 0.4882
# {473}
# Epoch 475/500, Train Loss: 1.5138, Valid Loss: 0.2425
# RMSE: 0.4925
# {474}
# Epoch 476/500, Train Loss: 1.5292, Valid Loss: 0.2385
# RMSE: 0.4883
# {475}
# Epoch 477/500, Train Loss: 1.5221, Valid Loss: 0.2334
# RMSE: 0.4831
# {476}
# Epoch 478/500, Train Loss: 1.5307, Valid Loss: 0.2307
# RMSE: 0.4803
# {477}
# Epoch 479/500, Train Loss: 1.5353, Valid Loss: 0.2361
# RMSE: 0.4859
# {478}
# Epoch 480/500, Train Loss: 1.5227, Valid Loss: 0.2456
# RMSE: 0.4956
# {479}
# Epoch 481/500, Train Loss: 1.5408, Valid Loss: 0.2387
# RMSE: 0.4886
# {480}
# Epoch 482/500, Train Loss: 1.5038, Valid Loss: 0.2399
# RMSE: 0.4898
# {481}
# Epoch 483/500, Train Loss: 1.5119, Valid Loss: 0.2314
# RMSE: 0.4811
# {482}
# Epoch 484/500, Train Loss: 1.5082, Valid Loss: 0.2381
# RMSE: 0.4880
# {483}
# Epoch 485/500, Train Loss: 1.5111, Valid Loss: 0.2382
# RMSE: 0.4880
# {484}
# Epoch 486/500, Train Loss: 1.5137, Valid Loss: 0.2370
# RMSE: 0.4868
# {485}
# Epoch 487/500, Train Loss: 1.4936, Valid Loss: 0.2364
# RMSE: 0.4863
# {486}
# Epoch 488/500, Train Loss: 1.5046, Valid Loss: 0.2311
# RMSE: 0.4807
# {487}
# Epoch 489/500, Train Loss: 1.5158, Valid Loss: 0.2418
# RMSE: 0.4917
# {488}
# Epoch 490/500, Train Loss: 1.5258, Valid Loss: 0.2368
# RMSE: 0.4866
# {489}
# Epoch 491/500, Train Loss: 1.5360, Valid Loss: 0.2397
# RMSE: 0.4896
# {490}
# Epoch 492/500, Train Loss: 1.5034, Valid Loss: 0.2378
# RMSE: 0.4876
# {491}
# Epoch 493/500, Train Loss: 1.5235, Valid Loss: 0.2416
# RMSE: 0.4915
# {492}
# Epoch 494/500, Train Loss: 1.5270, Valid Loss: 0.2455
# RMSE: 0.4955
# {493}
# Epoch 495/500, Train Loss: 1.4992, Valid Loss: 0.2391
# RMSE: 0.4890
# {494}
# Epoch 496/500, Train Loss: 1.4985, Valid Loss: 0.2431
# RMSE: 0.4931
# {495}
# Epoch 497/500, Train Loss: 1.4965, Valid Loss: 0.2395
# RMSE: 0.4894
# {496}
# Epoch 498/500, Train Loss: 1.4999, Valid Loss: 0.2474
# RMSE: 0.4974
# {497}
# Epoch 499/500, Train Loss: 1.5068, Valid Loss: 0.2438
# RMSE: 0.4937
# {498}
# Epoch 500/500, Train Loss: 1.5017, Valid Loss: 0.2473
# RMSE: 0.4973
# {499}

# %%
# Assuming you already have the data as tensors, convert them to DataLoader
# Modify the DataLoader to generate batches with the correct shape

# Update the input and output sizes according to your data
input_size = 64  # Number of features in your input data
output_size = 1006  # Replace ??? with the number of classes in your classification problem

# ... (Your previous code)

# Reshape the input data to have a 3-dimensional shape (batch_size, seq_length, input_size)
seq_length = 256
overlap = 20  # Adjust the overlap as needed
xgb_X_test_reshaped = []
for i in range(0, xgb_X_test.shape[0] - seq_length + 1, overlap):
    xgb_X_test_reshaped.append(xgb_X_test[i:i+seq_length])
xgb_X_test_reshaped = torch.stack(xgb_X_test_reshaped)

# Similarly, reshape the training target data
xgb_y_test_reshaped = []
for i in range(0, xgb_y_test.shape[0] - seq_length + 1, overlap):
    xgb_y_test_reshaped.append(xgb_y_test[i:i+seq_length])
xgb_y_test_reshaped = torch.stack(xgb_y_test_reshaped)



test_dataset = TensorDataset(xgb_X_test_reshaped, xgb_y_test_reshaped)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)  # Adjust batch_size as needed

# %%
def test_model(model, test_loader, criterion, device):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    test_loss = 0.0
    predictions = []
    targets_list = []
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            test_loss += loss.item()
            
            # Save the predictions and targets for visualization
            predictions.extend(outputs.cpu().numpy())
            targets_list.extend(targets.cpu().numpy())
    
    rmse_error = np.sqrt(test_loss / len(test_loader))
    return rmse_error, predictions, targets_list

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def visualize_predictions(predictions, targets, output_folder):
    os.makedirs(output_folder, exist_ok=True)  # Create the output folder if it doesn't exist
    
    for i in range(len(predictions)):
        fig, ax = plt.subplots(figsize=(5, 5))  # Set the figure size to 500x500 pixels

        ax.plot(np.arange(len(predictions[i])), predictions[i]**2, label='Predicted', marker='o')
        ax.plot(np.arange(len(targets[i])), targets[i], label='Actual', marker='x')
        ax.set_xlabel("Data Index")
        ax.set_ylabel("Values")
        ax.set_title(f"Predictions vs. Actual (Data Point {i + 1})")
        ax.legend()

        plt.tight_layout()  # To prevent overlapping of labels and ticks
        plt.savefig(os.path.join(output_folder, f"plot_{i + 1}.png"))  # Save the plot with a unique name
        plt.close()  # Close the current figure to release memory


output_folder = "output_plots"

# %%
# Assuming you have already trained your model and have the test_loader ready
# ...
criterion = RMSELoss()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Test the model on the test dataset
rmse_error, test_predictions, test_targets = test_model(model, test_loader, criterion, device)
print(f"RMSE Error on Test Dataset: {rmse_error:.4f}")
output_folder = "final_output"

# Visualize predictions versus actual on the test dataset
visualize_predictions(test_predictions, test_targets, output_folder)
# Out:
# RMSE Error on Test Dataset: 0.5634
